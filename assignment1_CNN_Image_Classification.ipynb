# %%
# !unzip "sample_data/part_2_cnn_dataset.zip" -d "sample_data/part_2_cnn_dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5499.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/55.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/550.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5500.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5501.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5502.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5503.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5504.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5505.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5506.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5507.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5508.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5509.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/551.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5510.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5511.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5512.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5513.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5514.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5515.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5516.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5517.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5518.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5519.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/552.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5520.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5521.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5522.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5523.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5524.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5525.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5526.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5527.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5528.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5529.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/553.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5530.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5531.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5532.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5533.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5534.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5535.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5536.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5537.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5538.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5539.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/554.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5540.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5541.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5542.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5543.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5544.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5545.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5546.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5547.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5548.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5549.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/555.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5550.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5551.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5552.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5553.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5554.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5555.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5556.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5557.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5558.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5559.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/556.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5560.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5561.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5562.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5563.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5564.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5565.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5566.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5567.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5568.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5569.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/557.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5570.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5571.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5572.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5573.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5574.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5575.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5576.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5577.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5578.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5579.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/558.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5580.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5581.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5582.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5583.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5584.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5585.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5586.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5587.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5588.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5589.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/559.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5590.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5591.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5592.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5593.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5594.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5595.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5596.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5597.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5598.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5599.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/56.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/560.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5600.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5601.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5602.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5603.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5604.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5605.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5606.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5607.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5608.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5609.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/561.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5610.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5611.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5612.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5613.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5614.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5615.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5616.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5617.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5618.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5619.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/562.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5620.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5621.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5622.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5623.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5624.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5625.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5626.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5627.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5628.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5629.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/563.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5630.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5631.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5632.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5633.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5634.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5635.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5636.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5637.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5638.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5639.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/564.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5640.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5641.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5642.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5643.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5644.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5645.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5646.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5647.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5648.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5649.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/565.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5650.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5651.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5652.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5653.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5654.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5655.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5656.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5657.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5658.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5659.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/566.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5660.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5661.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5662.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5663.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5664.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5665.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5666.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5667.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5668.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5669.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/567.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5670.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5671.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5672.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5673.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5674.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5675.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5676.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5677.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5678.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5679.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/568.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5680.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5681.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5682.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5683.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5684.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5685.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5686.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5687.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5688.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5689.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/569.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5690.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5691.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5692.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5693.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5694.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5695.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5696.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5697.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5698.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5699.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/57.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/570.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5700.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5701.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5702.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5703.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5704.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5705.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5706.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5707.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5708.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5709.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/571.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5710.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5711.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5712.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5713.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5714.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5715.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5716.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5717.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5718.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5719.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/572.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5720.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5721.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5722.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5723.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5724.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5725.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5726.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5727.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5728.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5729.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/573.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5730.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5731.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5732.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5733.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5734.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5735.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5736.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5737.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5738.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5739.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/574.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5740.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5741.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5742.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5743.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5744.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5745.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5746.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5747.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5748.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5749.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/575.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5750.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5751.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5752.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5753.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5754.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5755.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5756.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5757.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5758.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5759.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/576.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5760.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5761.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5762.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5763.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5764.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5765.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5766.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5767.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5768.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5769.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/577.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5770.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5771.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5772.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5773.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5774.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5775.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5776.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5777.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5778.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5779.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/578.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5780.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5781.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5782.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5783.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5784.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5785.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5786.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5787.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5788.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5789.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/579.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5790.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5791.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5792.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5793.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5794.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5795.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5796.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5797.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5798.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5799.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/58.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/580.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5800.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5801.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5802.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5803.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5804.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5805.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5806.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5807.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5808.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5809.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/581.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5810.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5811.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5812.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5813.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5814.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5815.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5816.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5817.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5818.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5819.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/582.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5820.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5821.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5822.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5823.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5824.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5825.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5826.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5827.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5828.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5829.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/583.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5830.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5831.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5832.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5833.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5834.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5835.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5836.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5837.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5838.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5839.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/584.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5840.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5841.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5842.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5843.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5844.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5845.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5846.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5847.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5848.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5849.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/585.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5850.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5851.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5852.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5853.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5854.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5855.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5856.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5857.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5858.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5859.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/586.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5860.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5861.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5862.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5863.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5864.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5865.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5866.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5867.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5868.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5869.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/587.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5870.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5871.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5872.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5873.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5874.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5875.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5876.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5877.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5878.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5879.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/588.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5880.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5881.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5882.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5883.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5884.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5885.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5886.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5887.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5888.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5889.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/589.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5890.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5891.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5892.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5893.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5894.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5895.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5896.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5897.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5898.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5899.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/59.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/590.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5900.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5901.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5902.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5903.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5904.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5905.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5906.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5907.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5908.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5909.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/591.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5910.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5911.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5912.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5913.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5914.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5915.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5916.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5917.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5918.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5919.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/592.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5920.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5921.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5922.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5923.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5924.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5925.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5926.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5927.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5928.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5929.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/593.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5930.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5931.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5932.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5933.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5934.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5935.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5936.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5937.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5938.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5939.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/594.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5940.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5941.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5942.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5943.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5944.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5945.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5946.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5947.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5948.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5949.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/595.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5950.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5951.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5952.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5953.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5954.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5955.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5956.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5957.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5958.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5959.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/596.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5960.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5961.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5962.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5963.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5964.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5965.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5966.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5967.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5968.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5969.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/597.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5970.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5971.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5972.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5973.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5974.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5975.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5976.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5977.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5978.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5979.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/598.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5980.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5981.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5982.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5983.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5984.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5985.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5986.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5987.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5988.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5989.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/599.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5990.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5991.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5992.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5993.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5994.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5995.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5996.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5997.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5998.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/5999.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/60.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/600.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6000.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6001.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6002.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6003.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6004.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6005.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6006.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6007.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6008.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6009.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/601.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6010.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6011.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6012.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6013.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6014.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6015.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6016.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6017.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6018.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6019.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/602.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6020.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6021.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6022.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6023.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6024.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6025.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6026.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6027.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6028.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6029.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/603.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6030.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6031.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6032.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6033.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6034.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6035.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6036.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6037.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6038.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6039.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/604.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6040.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6041.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6042.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6043.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6044.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6045.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6046.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6047.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6048.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6049.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/605.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6050.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6051.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6052.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6053.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6054.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6055.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6056.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6057.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6058.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6059.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/606.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6060.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6061.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6062.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6063.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6064.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6065.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6066.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6067.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6068.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6069.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/607.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6070.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6071.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6072.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6073.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6074.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6075.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6076.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6077.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6078.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6079.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/608.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6080.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6081.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6082.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6083.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6084.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6085.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6086.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6087.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6088.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6089.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/609.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6090.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6091.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6092.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6093.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6094.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6095.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6096.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6097.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6098.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6099.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/61.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/610.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6100.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6101.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6102.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6103.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6104.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6105.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6106.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6107.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6108.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6109.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/611.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6110.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6111.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6112.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6113.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6114.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6115.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6116.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6117.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6118.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6119.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/612.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6120.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6121.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6122.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6123.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6124.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6125.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6126.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6127.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6128.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6129.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/613.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6130.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6131.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6132.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6133.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6134.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6135.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6136.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6137.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6138.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6139.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/614.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6140.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6141.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6142.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6143.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6144.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6145.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6146.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6147.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6148.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6149.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/615.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6150.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6151.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6152.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6153.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6154.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6155.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6156.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6157.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6158.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6159.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/616.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6160.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6161.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6162.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6163.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6164.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6165.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6166.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6167.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6168.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6169.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/617.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6170.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6171.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/6172.jpg
# ...
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9774.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9775.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9776.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9777.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9778.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9779.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/978.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9780.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9781.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9782.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9783.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9784.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9785.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9786.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9787.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9788.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9789.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/979.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9790.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9791.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9792.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9793.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9794.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9795.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9796.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9797.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9798.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9799.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/98.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/980.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9800.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9801.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9802.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9803.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9804.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9805.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9806.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9807.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9808.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9809.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/981.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9810.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9811.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9812.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9813.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9814.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9815.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9816.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9817.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9818.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9819.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/982.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9820.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9821.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9822.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9823.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9824.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9825.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9826.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9827.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9828.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9829.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/983.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9830.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9831.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9832.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9833.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9834.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9835.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9836.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9837.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9838.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9839.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/984.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9840.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9841.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9842.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9843.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9844.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9845.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9846.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9847.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9848.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9849.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/985.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9850.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9851.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9852.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9853.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9854.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9855.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9856.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9857.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9858.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9859.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/986.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9860.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9861.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9862.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9863.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9864.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9865.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9866.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9867.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9868.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9869.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/987.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9870.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9871.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9872.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9873.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9874.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9875.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9876.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9877.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9878.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9879.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/988.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9880.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9881.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9882.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9883.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9884.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9885.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9886.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9887.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9888.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9889.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/989.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9890.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9891.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9892.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9893.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9894.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9895.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9896.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9897.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9898.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9899.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/99.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/990.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9900.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9901.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9902.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9903.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9904.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9905.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9906.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9907.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9908.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9909.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/991.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9910.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9911.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9912.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9913.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9914.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9915.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9916.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9917.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9918.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9919.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/992.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9920.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9921.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9922.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9923.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9924.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9925.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9926.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9927.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9928.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9929.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/993.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9930.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9931.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9932.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9933.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9934.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9935.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9936.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9937.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9938.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9939.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/994.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9940.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9941.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9942.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9943.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9944.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9945.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9946.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9947.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9948.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9949.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/995.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9950.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9951.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9952.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9953.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9954.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9955.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9956.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9957.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9958.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9959.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/996.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9960.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9961.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9962.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9963.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9964.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9965.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9966.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9967.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9968.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9969.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/997.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9970.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9971.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9972.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9973.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9974.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9975.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9976.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9977.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9978.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9979.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/998.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9980.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9981.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9982.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9983.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9984.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9985.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9986.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9987.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9988.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9989.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/999.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9990.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9991.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9992.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9993.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9994.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9995.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9996.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9997.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9998.jpg
#   inflating: sample_data/part_2_cnn_dataset/vehicles/9999.jpg

# %% [markdown]
# Load images and convert into numpy arrays

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# Folder path and classes
data_dir = 'sample_data/part_2_cnn_dataset'
classes = ['vehicles', 'food', 'dogs']

# Load images
def load_images_from_folder(folder, label):
    images = []
    labels = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = Image.open(img_path).resize((64, 64))  # Ensure the images are 64x64
        img_array = np.array(img)
        if img_array.shape == (64, 64, 3):  # Ensure the image is in RGB format
            images.append(img_array)
            labels.append(label)
    return images, labels

all_images = []
all_labels = []

for idx, class_name in enumerate(classes):
    folder_path = os.path.join(data_dir, class_name)
    images, labels = load_images_from_folder(folder_path, idx)
    all_images.extend(images)
    all_labels.extend(labels)

# Convert images to numpy arrays
all_images = np.array(all_images)
all_labels = np.array(all_labels)

print(f"Total number of images: {len(all_images)}")
print(f"Image array shape: {all_images.shape}")
print(f"Label array shape: {all_labels.shape}")
# Out:
# Total number of images: 30000
# Image array shape: (30000, 64, 64, 3)
# Label array shape: (30000,)

# %% [markdown]
# Display sample images

# %%
# sample images
def display_sample_images(images, labels, classes, num_samples=5):
    plt.figure(figsize=(10, 5))
    for i in range(num_samples):
        index = np.random.randint(0, len(images))
        plt.subplot(1, num_samples, i + 1)
        plt.imshow(images[index])
        plt.title(classes[labels[index]])
        plt.axis('off')
    plt.show()

display_sample_images(all_images, all_labels, classes)

# %% [markdown]
# Main Statistics about the dataset

# %%
# Main statistics about the dataset
print(f"Total number of images: {len(all_images)}")
print(f"Image array shape: {all_images.shape}")
print(f"Label array shape: {all_labels.shape}")

# Number of images per class
unique, counts = np.unique(all_labels, return_counts=True)
class_distribution = dict(zip(unique, counts))

print("Number of images per class:")
for class_idx, num_images in class_distribution.items():
    print(f"{classes[class_idx]}: {num_images}")
# Out:
# Total number of images: 30000
# Image array shape: (30000, 64, 64, 3)
# Label array shape: (30000,)
# Number of images per class:
# vehicles: 10000
# food: 10000
# dogs: 10000

# %% [markdown]
# Plotting the class distribution

# %%
import seaborn as sns

# Plotting the class distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=list(class_distribution.keys()), y=list(class_distribution.values()))
plt.xticks(ticks=[0, 1, 2], labels=classes)
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.show()

# Display a few sample images from the dataset
display_sample_images(all_images, all_labels, classes)

# %% [markdown]
# Plot histogram of pixel values

# %%
# Flatten all images and plot histogram of pixel values
all_images_flat = all_images.flatten()

plt.figure(figsize=(10, 5))
plt.hist(all_images_flat, bins=256, color='blue', alpha=0.7)
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram of Image Pixel Intensities')
plt.show()

# %% [markdown]
# VGG-13 Version B model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

# Define VGG-13 Version B model with 13 weight layers
class VGG13(nn.Module):
    def __init__(self, num_classes=3): # 3 classes
        super(VGG13, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(512 * 2 * 2, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# Model creation
model = VGG13(num_classes=3)
print(model)
# Out:
# VGG13(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU(inplace=True)
#     (17): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (20): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU(inplace=True)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU(inplace=True)
#     (24): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# Data augmentation, normalization and dataset split

# %%
class CustomDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Data augmentation and normalization
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(9),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.489, 0.446, 0.416], std=[0.309, 0.254, 0.125]),
])

dataset = CustomDataset(all_images, all_labels, transform=transform)

# create train_dataset and val_dataset
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# create train_loader, val_loader and test_loader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# Training the model

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=10)

num_epochs = 5
best_val_loss = float('inf')
patience = 10
early_stopping_counter = 0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Training loop with epoch
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    # print(len(train_loader))
    # i=0
    for inputs, labels in train_loader:
        # i=i+1
        # print(i)
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        i, predicted = torch.max(outputs, 1)
        correct_train += (predicted == labels).sum().item()
        total_train += labels.size(0)

    train_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)

    # Validation
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    # j=0
    with torch.no_grad():
        for inputs, labels in val_loader:
            # j=j+1
            # print(j)
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            i, predicted = torch.max(outputs, 1)
            correct_val += (predicted == labels).sum().item()
            total_val += labels.size(0)

    val_loss /= len(val_loader)
    val_accuracy = 100 * correct_val / total_val
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

    # Update learning rate scheduler
    scheduler.step(val_loss)

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        # Save best model weights to pickle file
        torch.save(model.state_dict(), 'dsivapra_rkota2_assignment1_part_2.pkl')
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= patience:
            print("Early stopping triggered")
            break

    print(f"Epoch {epoch+1},\n "
          f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%,\n "
          f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%\n")

# Load best model weights from pickle file
model.load_state_dict(torch.load('dsivapra_rkota2_assignment1_part_2.pkl'))
# Out:
# Epoch 1,
#  Train Loss: 0.7015, Train Accuracy: 67.58%,
#  Validation Loss: 0.5267, Validation Accuracy: 80.28%
#
# Epoch 2,
#  Train Loss: 0.4393, Train Accuracy: 83.40%,
#  Validation Loss: 0.3593, Validation Accuracy: 85.88%
#
# Epoch 3,
#  Train Loss: 0.3625, Train Accuracy: 86.60%,
#  Validation Loss: 0.3299, Validation Accuracy: 87.73%
#
# Epoch 4,
#  Train Loss: 0.3195, Train Accuracy: 88.53%,
#  Validation Loss: 0.2825, Validation Accuracy: 89.83%
#
# Epoch 5,
#  Train Loss: 0.2924, Train Accuracy: 89.53%,
#  Validation Loss: 0.2622, Validation Accuracy: 90.53%
# <All keys matched successfully>

# %% [markdown]
# Calculate Test loss and accuracy

# %%
model.eval()
test_loss = 0.0
correct_test = 0
total_test = 0
all_labels = []
all_predictions = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()

        i, predicted = torch.max(outputs, 1)
        correct_test += (predicted == labels).sum().item()
        total_test += labels.size(0)

        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

test_loss /= len(test_loader)
test_accuracy = 100 * correct_test / total_test

print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Loss: 0.2645, Test Accuracy: 90.47%

# %% [markdown]
# Plotting training and validation accuracy and loss

# %%
# Plotting training and validation accuracy and loss
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracies, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracies, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_losses, 'b', label='Training loss')
plt.plot(epochs, val_losses, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# Confusion Matrix and evaluation metrics

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Confusion Matrix
cm = confusion_matrix(all_labels, all_predictions)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification Report
print("Classification Report:\n", classification_report(all_labels, all_predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      1991
#            1       0.87      0.93      0.90      2021
#            2       0.89      0.87      0.88      1988
#
#     accuracy                           0.90      6000
#    macro avg       0.91      0.90      0.90      6000
# weighted avg       0.91      0.90      0.90      6000
